# %% [markdown]
# # Khám phá LSTM cho sinh viên khá/giỏi

# %% [markdown]
# LSTM là model học chuỗi. Khác với Random Forest dùng các cột lag/rolling đã tạo sẵn, LSTM nhận cả một cửa sổ nhiều bước thời gian.
#
# **Không bắt buộc:** phần này dành cho sinh viên muốn tìm hiểu sâu hơn về deep learning cho time-series.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
print(ROOT)

# %%
# Chạy sau khi đã cài torch: pip install -r requirements_lstm.txt
# %run ../src/train_lstm.py --datasets appliances --epochs 12

# %%
import pandas as pd
path = ROOT / 'outputs/lstm_metrics.csv'
if path.exists():
    display(pd.read_csv(path))
else:
    print('LSTM metrics not found. Did you install torch and run train_lstm.py?')

# %% [markdown]
# **Câu hỏi:** LSTM có luôn tốt hơn Random Forest không? Nếu không, có thể do dữ liệu ít, tuning chưa đủ, sequence length chưa hợp lý, hoặc target quá nhiễu?
