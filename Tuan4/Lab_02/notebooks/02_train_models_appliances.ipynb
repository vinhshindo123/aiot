# %% [markdown]
# # Train AI models trên UCI Appliances Energy Prediction

# %% [markdown]
# Notebook này tập trung vào target `Appliances`. Sinh viên chạy từng phần và ghi lại model nào tốt hơn baseline.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
print(ROOT)

# %%
from prepare_datasets import prepare_appliances
prepare_appliances()

# %%
# %run ../src/train_classical_models.py

# %%
import pandas as pd
metrics = pd.read_csv(ROOT / 'outputs/metrics_all_models.csv')
display(metrics[(metrics.dataset=='appliances') & (metrics.split=='test')].sort_values('mae'))

# %% [markdown]
# **Câu hỏi:** Random Forest có hơn Last Value không? Nếu hơn ít, có thể do dữ liệu khó, horizon ngắn, hay baseline đã mạnh?
