# %% [markdown]
# # Train AI models trên Occupancy/CO2 forecasting

# %% [markdown]
# Notebook này dùng schema Occupancy Detection nhưng chuyển bài toán sang forecasting `CO2`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
print(ROOT)

# %%
from prepare_datasets import prepare_co2
prepare_co2()

# %%
# %run ../src/train_classical_models.py

# %%
import pandas as pd
metrics = pd.read_csv(ROOT / 'outputs/metrics_all_models.csv')
display(metrics[(metrics.dataset=='co2') & (metrics.split=='test')].sort_values('mae'))

# %% [markdown]
# **Câu hỏi:** CO2 có tính quán tính theo thời gian không? Điều đó làm Last Value mạnh hơn hay yếu hơn?
